# %%
# !pip install openai -q

# %%
import openai
import pandas as pd
import numpy as np
from getpass import getpass
from openai.embeddings_utils import get_embedding
from openai.embeddings_utils import cosine_similarity

openai.api_key = getpass()

# %%
#create embeddings from any string 
get_embedding("This table- Issue contains column named -name of varchar dataype. This is not a primary key. It does not have any referances. This column describes - name of the issue.", engine='text-embedding-ada-002')
# Out:
# [-0.0014084808062762022,
#  0.011001030914485455,
#  0.003803838975727558,
#  -0.01431228592991829,
#  -0.018157172948122025,
#  0.017185689881443977,
#  -0.020195921882987022,
#  -0.014408065937459469,
#  -0.01907392591238022,
#  -0.014161773957312107,
#  0.0061778174713253975,
#  -0.0030375979840755463,
#  -0.00862021092325449,
#  0.028542473912239075,
#  0.0017360146157443523,
#  0.00502845598384738,
#  0.011315736919641495,
#  -0.01579003594815731,
#  0.021222136914730072,
#  -0.016775203868746758,
#  -0.0017496974905952811,
#  0.0033813801128417253,
#  -0.016077376902103424,
#  0.023370347917079926,
#  -0.013477630913257599,
#  0.03144324570894241,
#  0.016761520877480507,
#  -0.018622390925884247,
#  -0.002820382360368967,
#  0.0065506757237017155,
#  0.010330569930374622,
#  -0.01080946996808052,
#  -0.003222316736355424,
#  -0.03595859184861183,
#  -0.03054017387330532,
#  0.011295212432742119,
#  0.017199372872710228,
#  0.01424387190490961,
#  0.024369198828935623,
# ...

# %%
#create embedding for any CSV file and perform symentic search
df = pd.read_csv('Documents/jsonld.csv')
print(df)
df['embedding'] = df['JSON'].apply(lambda x: get_embedding(x, engine='text-embedding-ada-002'))
df.to_csv('Documents/json_embeddings.csv')
df = pd.read_csv('Documents/json_embeddings.csv')
print(df)
df['embedding'] = df.embedding.apply(eval).apply(np.array)
embedding = get_embedding("issue", model='text-embedding-ada-002')
df['similarities'] = df.embedding.apply(lambda x: cosine_similarity(x, embedding))
print(df)

#df['embedding'] = df['embedding'].apply(eval).apply(np.array)
#search_term = input('table details  ')
#search_term_vector = get_embedding(search_term, engine="text-embedding-ada-002")
#df["similarities"] = df['embedding'].apply(lambda x: cosine_similarity(x, search_term_vector))
#df.sort_values("similarities", ascending=False).head(20)
# Out:
#                                                 JSON
# 0  JSON-LD  by using Public ontology rdf, rdfs, o...
#    Unnamed: 0                                               JSON  \
# 0           0  JSON-LD  by using Public ontology rdf, rdfs, o...
#
#                                            embedding
# 0  [0.014903397299349308, 0.025061095133423805, -...
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# File c:\python38\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File c:\python38\lib\site-packages\openai\embeddings_utils.py:23, in get_embedding(text, engine, **kwargs)
#      21 text = text.replace("\n", " ")
# ---> 23 return openai.Embedding.create(input=[text], engine=engine, **kwargs)["data"][0]["embedding"]
#
# ...

# %%
embedding = get_embedding("issue", model='text-embedding-ada-002')
# Out:
# ---------------------------------------------------------------------------
# InvalidRequestError                       Traceback (most recent call last)
# File c:\python38\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File c:\python38\lib\site-packages\openai\embeddings_utils.py:23, in get_embedding(text, engine, **kwargs)
#      21 text = text.replace("\n", " ")
# ---> 23 return openai.Embedding.create(input=[text], engine=engine, **kwargs)["data"][0]["embedding"]
#
# File c:\python38\lib\site-packages\openai\api_resources\embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      32 try:
# ---> 33     response = super().create(*args, **kwargs)
#      35     # If a user specifies base64, we'll just return the encoded string.
#      36     # This is only for the default case.
#
# ...

# %%
from dotenv import load_dotenv
# Load environment variables from the .env file
load_dotenv()
openai.api_key ="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"
#openai.api_key = getpass()
import llama_index
import os
from llama_index import (
    GPTKeywordTableIndex,
    SimpleDirectoryReader,
    LLMPredictor,
    ServiceContext
)

from llama_index import GPTVectorStoreIndex
from langchain.llms import OpenAI
documents = SimpleDirectoryReader('docs').load_data()
#df = pd.read_csv('Documents/rawdata.csv')
llm_predictor = LLMPredictor(llm=OpenAI(model_name='text-davinci-003', temperature=0, max_tokens=256))
service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor)
service_context = ServiceContext.from_defaults()
index = GPTVectorStoreIndex.from_documents (documents, service_context=service_context)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File c:\python38\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File c:\python38\lib\site-packages\llama_index\embeddings\openai.py:150, in get_embeddings(list_of_text, engine, **kwargs)
#     148 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 150 data = openai.Embedding.create(input=list_of_text, model=engine, **kwargs).data
#     151 return [d["embedding"] for d in data]
#
# File c:\python38\lib\site-packages\openai\api_resources\embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      32 try:
# ---> 33     response = super().create(*args, **kwargs)
#      35     # If a user specifies base64, we'll just return the encoded string.
# ...

# %%
load_dotenv()
# Out:
# True

# %%
service_context = ServiceContext.from_defaults(llm_predictor=llm_predictor)

# %%
service_context = ServiceContext.from_defaults()

# %%
index = GPTVectorStoreIndex.from_documents(documents, service_context=service_context)
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# File c:\python38\lib\site-packages\tenacity\__init__.py:382, in Retrying.__call__(self, fn, *args, **kwargs)
#     381 try:
# --> 382     result = fn(*args, **kwargs)
#     383 except BaseException:  # noqa: B902
#
# File c:\python38\lib\site-packages\llama_index\embeddings\openai.py:150, in get_embeddings(list_of_text, engine, **kwargs)
#     148 list_of_text = [text.replace("\n", " ") for text in list_of_text]
# --> 150 data = openai.Embedding.create(input=list_of_text, model=engine, **kwargs).data
#     151 return [d["embedding"] for d in data]
#
# File c:\python38\lib\site-packages\openai\api_resources\embedding.py:33, in Embedding.create(cls, *args, **kwargs)
#      32 try:
# ---> 33     response = super().create(*args, **kwargs)
#      35     # If a user specifies base64, we'll just return the encoded string.
# ...

# %%
# build index
query_engine = index.as_query_engine()
query = input("Enter your query: ")
response = query_engine.query(query)
print(response)
# Out:
# Enter your query:    given db schema in rawdata , map to corresponding fields in jsonld file and don't map fields from same file
# Issue Table:
# name -> msrpc:Issue/msrpc3:_Issue_/rdfs:label
# issue_key -> msrpc:Issue/@id
# statusid -> msrpc:Issue/msrpcx:_IssueStatus_
# actioncompletiondt -> msrpc:Issue/msrpc:actionCompletionDateTime
# verificationdt -> msrpc:Issue/msrpc:readyForVerificationAtDateTime
# closedtof -> msrpc:Issue/msrpc:closedAtDateTime
#
# Enum Table:
# name -> msrpc:IssueStatus/rdfs:label
# enumid -> msrpc:IssueStatus/@id

# %%
GPTVectorStoreIndex
# Out:
#   Cell In[97], line 1
#     GPTVectorStoreIndex.
#                         ^
# SyntaxError: invalid syntax

# %%
pwd
# Out:
# 'C:\\Users\\Administrator'

# %%
texts = ["eating food", "I am hungry", "I am traveling" , "exploring new places"]
resp = openai.Embedding.create(
    input= texts,
    engine="text-similarity-davinci-001")


embedding_a = resp['data'][0]['embedding']
embedding_b = resp['data'][1]['embedding']
embedding_c = resp['data'][2]['embedding']
embedding_d = resp['data'][3]['embedding']

li = []
for ele in resp['data']:
    li.append(ele["embedding"])

## Finding text similarity percentages
for i in range(len(texts) - 1):
    for j in range(i + 1, len(resp["data"])):
        print("text similarity percentage between",texts[i], "and", texts[j],"is ", np.dot(resp['data'][i]['embedding'],resp['data'][j]['embedding'])*100)
# Out:
# text similarity percentage between eating food and I am hungry is  87.43983922527889
# text similarity percentage between eating food and I am traveling is  78.91278388577065
# text similarity percentage between eating food and exploring new places is  77.60522408432806
# text similarity percentage between I am hungry and I am traveling is  81.72979053677594
# text similarity percentage between I am hungry and exploring new places is  76.79649522722389
# text similarity percentage between I am traveling and exploring new places is  85.293386957823

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score

# load data
datafile_path = "Documents/fine_food_reviews_with_embeddings_1k.csv"

df = pd.read_csv(datafile_path)
df["embedding"] = df.embedding.apply(eval).apply(np.array)  # convert string to array

# split data into train and test
X_train, X_test, y_train, y_test = train_test_split(
    list(df.embedding.values), df.Score, test_size=0.2, random_state=42
)

# train random forest classifier
clf = RandomForestClassifier(n_estimators=100)
clf.fit(X_train, y_train)
preds = clf.predict(X_test)
probas = clf.predict_proba(X_test)

report = classification_report(y_test, preds)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.88      0.35      0.50        20
#            2       1.00      0.38      0.55         8
#            3       1.00      0.18      0.31        11
#            4       1.00      0.26      0.41        27
#            5       0.74      1.00      0.85       134
#
#     accuracy                           0.77       200
#    macro avg       0.92      0.43      0.52       200
# weighted avg       0.82      0.77      0.72       200
